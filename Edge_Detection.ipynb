# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/prathgan/Constellation-Demos/blob/master/Edge_Detection.ipynb)

# %%
from google.colab import files

# %%
# !git clone https://github.com/ConstellationCV/Constellation-2.0.git
# Out:
# Cloning into 'Constellation-2.0'...
# remote: Counting objects: 320, done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 320 (delta 23), reused 50 (delta 10), pack-reused 250
# Receiving objects: 100% (320/320), 1.41 MiB | 37.08 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
# !pip install Constellation-2.0/.
# Out:
# Processing ./Constellation-2.0
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/e9/ea/6d/15d85deb216d5f6d76243007a92dbccc215488f1b57a8cde34
# done
#   Stored in directory: /root/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built constellationcv sklearn
# ...

# %%
import constellationcv as cv

# %%
files.upload()
# Out:
#      <input type="file" id="files-c80bf230-deab-402d-bc9b-f0ac2cfecb1b" name="files[]" multiple disabled />
#      <output id="result-c80bf230-deab-402d-bc9b-f0ac2cfecb1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png
# ...

# %%
e = cv.edge_detector("image.png")

# %%
edgeMat = e.findEdgeMatrix()
# Out:
# /usr/local/lib/python3.6/dist-packages/constellationcv/arithmetic_toolkit.py:32: RuntimeWarning: overflow encountered in ubyte_scalars
#   return sum(v_i * w_i for v_i,w_i in zip(v,w))
# /usr/local/lib/python3.6/dist-packages/constellationcv/arithmetic_toolkit.py:11: RuntimeWarning: overflow encountered in ubyte_scalars
#   return [v_i - w_i for v_i,w_i in zip(v,w)]

# %%
e.outputEdgeImage(edgeMat,"edges_output.png")

# %%
files.download('edges_output.png')
